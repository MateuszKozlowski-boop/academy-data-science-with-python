# %%
# %%HTML
# <link rel="stylesheet" type="text/css" href="css/custom.css">

# %% [markdown]
# # Machine Learning
#
# <img src='images/gdd-logo.png' width='500px' align='right' style="padding: 15px">
#
# Machine Learning is more than just a buzzword!
#
# It can used anywhere from automating mundane tasks to offering intelligent insights.

# %% [markdown]
# ## Defining Machine Learning
#
# Machine Learning is the study of computer algorithms that can improve **automatically** through experience and/or by exposure to data.

# %% [markdown]
# This mean machine learning algorithms differ to hard-coded, rule-based algorithms. For example,
#
# <img src='images/01_Machine_Learning_Intro/rule-based.png' width='600px' align='left'>

# %% [markdown]
# <img src='images/01_Machine_Learning_Intro/ml.jpeg' width='500px' align='right' style="padding: 20px">
#
# ## Applications
#
# Can you think of 5 examples of Machine Learning?

# %% [markdown]
# Examples could be:
#
# - Forecasting sales for supermarkets
# - Image recognition for medical purposes
# - Speech recognitions for virtual assistants
# - Fraud detection in banks
# - Recommender systems for online videos
# - Sentiment analysis on reviews on webshops

# %% [markdown]
# ---
#
# ## Brief history of Machine Learning
#
# The set of techniques that we call 'Machine Learning' today were developed during the past century, by scientists from different technical fields, most notably computer science and statistical science.
#
# <img src='images/01_Machine_Learning_Intro/ml-timeline.png' width='500px'>

# %% [markdown]
# ## Machine Learning timeline
#
# A variety of Machine Learning techniques, or models, have been developed over the past century.
#
# <img src='images/01_Machine_Learning_Intro/ml-timeline-2.png' width='500px'>

# %% [markdown]
# ---
# ### Advancements in the last decades
#
# There has been big advancements in Machine Learning from the 1990s to today, due to:
# - the increase in **computational resources** ,
# - the increase in **available data** for model training and
# - **free to access** machine learning models (meaning they don't need to be implemented from scratch).
#
# Nowadays, you can run quite advanced algorithms that learn from millions of datapoints from a laptop the size of a book!

# %% [markdown]
# ---
# ## State of the art
#
# ### AlphaFold - DeepMind

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('gg7WjuFs8F4', width=600, height=450, end=42)
# until around 1.29

# %% [markdown]
# ## State of the art
#
# ### DALL·E 2 - OpenAI
#
# <img src=images/01_Machine_Learning_Intro/dall-e.gif width=800px height=600px>

# %% [markdown]
# ## State of the art
#
# ### ChatGPT - OpenAI
#
# <img src=images/01_Machine_Learning_Intro/chat-gpt.gif width=800px height=600px>

# %% [markdown]
# ---
#
# ## Approaches to Machine Learning
#
# There are three main approaches to performing Machine Learning:
#
#
# <img src='images/01_Machine_Learning_Intro/ml-types.png' width=800px height=600px>

# %% [markdown]
# ### An example of reinforcement learning

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('kopoLzvh5jY', width=600, height=450)

# %% [markdown]
# |Approach|Short Summary|
# |:---:|:---:|
# |**Supervised**|All data is **labeled** and the algorithm learns to **predict** the output from the data input|
# |**Unsupervised**|Add data is **unlabeled** and the algorithm learns the **inherent structure** from the input data|
# |**Reinforcement Learning**|An agent **maximises the level of reward** by interacting within an environment. The agent receives feedback in the form of rewards or penalties based on its actions.|

# %% [markdown]
# ![](images/01_Machine_Learning_Intro/ml-robot.jpeg)

# %% [markdown]
# Some also consider ***semi-supervised*** to be the fourth type of Machine Learning. This is where some data is **labeled** but most of it is **unlabeled** and a **mixture of supervised and unsupervised** techniques can be used

# %% [markdown]
# <img src='images/01_Machine_Learning_Intro/question.jpg' width='400px' align='right' style="padding: 20px">
#
# ## <mark>Exercise: Which ML type?</mark>
# Is it supervised, unsupervised or reinforcement learning?
#
# - Clustering similarly behaving customers who visit a webshop
# - Predicting how big a tree will get in 10 years
# - Teach a robot to navigate a complex environment
# - Diagnose a patient with a disease based on a blood test

# %% [markdown]
# ---
# ### Next Steps
#
# We will only be looking at supervised learning over this training. This is because it is the most common form of machine learning and there is so much to learn in this one area of machine learning.
#
#
# Machine Learning introduces quite a bit of **new terminology**. Please make sure to take note of the terms introduced with a 🔔.
