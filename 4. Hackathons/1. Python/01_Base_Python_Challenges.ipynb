# %% [markdown]
# <img src=images/gdd-logo.png align=right width=300px>
#
#
# # Base Python Challenges
#
# This notebook contains a number of Base Python challenges that give you an opportunity to put your base Python skills to a practical use. There are usually several alternative ways to achieve the provided objectives and you can use any approaches you like. Looking things up online is also an option if necessary

# %% [markdown]
# ## Challenge 1: Parsing email data
#
# You received a list of teammates' names and emails. The problem is - it is a single piece of unprocessed text. Try to automatically parse this string using as little code as possible to get the following:
#
# 1. A new string where only emails are contained and separated with a ;
# 2. A list of first and last names, for example "Rutte, M. (Mark)" should become "Mark Rutte"
#
# You can find the original string with names and emails below:

# %%
emails = """
Rutte, M. (Mark) <Mark.Rutte@vvd.nl>;
Kaag, S.A.M. (Sigrid) <S.Kaag@d66.nl>;
de Jonge, H.M. (Hugo) <Hugo.de.Jonge@cda.nl>;
Ollongren, K.H. (Kajsa) <K.Ollongren@d66.nl>;
Schouten, C.J. (Carola) <Carola.Schouten@cu.nl>;
Koolmees, W. (Wouter) <W.Koolmees@d66.nl>;
Zijlstra, H. (Halbe) <Halbe.Zijlstra@vvd.nl>;
Blok, S.A. (Stef) <Stef.Blok@vvd.nl>;

"""

# %%
#your solution here

# %% [markdown]
# ## Challenge 2: Finding the Silver Medal Winner
#
# ### Part 1:
#
# You are given a list of numbers. Each number represents the number of meters that a sportsman managed to jump. The list is sorted in accordance to a sportsman's number: the first element is from sportsman #1, the last one is from sportsman #n. From this list, find the number of the one (or multiple) sportsman who won the silver medal (second place).
#
# **Example:** `[4, 2, 5, 3, 6] --> 3` (Sportsman #3 had the second highest number and got the silver medal)

# %%
list_of_results1 = [4, 2, 5, 3, 6]
list_of_results2 = [6, 5, 5, 3, 4]
list_of_results3 = [1, 1, 6, 6, 2, 2, 8, 7, 2]
list_of_results4 = [] ## make your own list for testing

# %%
#your solution here

def list_silver_medal_winner(...):
    ...

# %%
#test
find_silver_medal_winner(list_of_results1)

# %% [markdown]
# ### Part 2:
# now instead of the lists above, you get dictionaries where keys correspond to sportsmen names and values to the number of meters that a sportsman managed to jump. From a dictionary like that, find the name of the one (or multiple) sportsman who won the silver medal (second place).
#
# **Example:** `{'Eric' : 4, 'Greg' : 2, 'Molly' : 5, 'Asphen' : 3, 'Rick' : 6} --> 'Molly'` (Molly had the second highest number and got the silver medal)

# %%
dict_of_results1 = {'Eric' : 4, 'Greg' : 2, 'Molly' : 5, 'Asphen' : 3, 'Rick' : 6}

dict_of_results2 = {'Afke' : 3, 'Bob' : 8, 'Ross' : 8, 'Lisanne' : 9, 'Vadim' : 1}

dict_of_results3 = {} ## make your own dictionary for testing

# %%
#your solution here

def dict_silver_medal_winner(...):
    ...

# %%
#test
dict_silver_medal_winner(dict_of_results1)

# %% [markdown]
# ## Challenge 3: Happy Sets
#
# You are given a list of *n* integers ( **k** ) and two distinct sets of integers (**a** and **b**). You like all the integers in set **a** and dislike all the integers in set **b**. Your initial happiness is **0**. For each  integer in the list **k**, if it is contained in **a**, you add **+1** to your happiness. If it is contained in **b**, you add **-1** to your happiness. Otherwise, your happiness does not change.
#
# Write a function that given **k**, **a** and **b** calculates your total happiness.

# %%
# examples for testing

k1 = [1, 9, 5, 2, 3, 3, 8, 6, 2]
a1 = {1, 3, 5}
b1 = {2, 4, 6}

k2 = [6, 6, 5, 4, 4, 6, 8, 6, 7, 8, 0, 0, 1]
a2 = {2, 3, 4, 7, 9}
b2 = {6, 8}

# %%
#your solution here

def get_happiness(k, a, b):
    ...

# %%
#test
get_happiness(k1, a1, b1)
