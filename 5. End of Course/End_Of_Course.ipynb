# %% [markdown]
# <img src=images/ing-icon.png width=70px align=left>
# <h2><center><font color=#FF6200>We greatly value your feedback! Please fill out our training evaluation form and tell us about your experience.</font></center></h2>
#
# <img src=images/ing-survey-qr.png width=200px>
#
#
# <img src=images/ing-lion.svg width=80px align=right>
# <h3><center><font color=#FF6200>Scan the QR code to go to the evaluation form.
# The form is also available through the following link: </font></center></h3>
# <a href=https://forms.office.com/r/cww2whwDJh><center>https://forms.office.com/r/cww2whwDJh</center>
